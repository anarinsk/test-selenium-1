# %%
! ./install_chrome.sh
# Out:
# Get:1 http://mirror.kakao.com/ubuntu bionic InRelease [242 kB]
# Get:2 http://mirror.kakao.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://mirror.kakao.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:4 http://mirror.kakao.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://mirror.kakao.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# Get:6 http://mirror.kakao.com/ubuntu bionic/universe amd64 Packages [11.3 MB]
# Get:7 http://mirror.kakao.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# Get:8 http://mirror.kakao.com/ubuntu bionic/main amd64 Packages [1,344 kB]
# Get:9 http://mirror.kakao.com/ubuntu bionic-updates/multiverse amd64 Packages [20.1 kB]
# Get:10 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 Packages [1,230 kB]
# Get:11 http://mirror.kakao.com/ubuntu bionic-updates/universe amd64 Packages [1,387 kB]
# Get:12 http://mirror.kakao.com/ubuntu bionic-updates/restricted amd64 Packages [73.6 kB]
# Get:13 http://mirror.kakao.com/ubuntu bionic-backports/main amd64 Packages [8,286 B]
# Get:14 http://mirror.kakao.com/ubuntu bionic-backports/universe amd64 Packages [8,158 B]
# Get:15 http://mirror.kakao.com/ubuntu bionic-security/main amd64 Packages [933 kB]
# Get:16 http://mirror.kakao.com/ubuntu bionic-security/universe amd64 Packages [856 kB]
# Get:17 http://mirror.kakao.com/ubuntu bionic-security/restricted amd64 Packages [59.3 kB]
# Get:18 http://mirror.kakao.com/ubuntu bionic-security/multiverse amd64 Packages [8,815 B]
# Fetched 18.0 MB in 2s (9,495 kB/s)
# Reading package lists... Done
# --2020-06-05 01:11:13--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 172.217.26.142, 2404:6800:4005:805::200e
# Connecting to dl.google.com (dl.google.com)|172.217.26.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68654544 (65M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb’
#
# google-chrome-stabl 100%[===================>]  65.47M  4.11MB/s    in 17s
#
# 2020-06-05 01:11:30 (3.97 MB/s) - ‘google-chrome-stable_current_amd64.deb’ saved [68654544/68654544]
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'google-chrome-stable' instead of './google-chrome-stable_current_amd64.deb'
# The following additional packages will be installed:
#   at-spi2-core dconf-gsettings-backend dconf-service glib-networking
#   glib-networking-common glib-networking-services gsettings-desktop-schemas
#   libappindicator3-1 libatk-bridge2.0-0 libatspi2.0-0 libcairo-gobject2
#   libcolord2 libdbusmenu-glib4 libdbusmenu-gtk3-4 libdconf1 libepoxy0
#   libgtk-3-0 libgtk-3-bin libgtk-3-common libindicator3-7 libjson-glib-1.0-0
#   libjson-glib-1.0-common libproxy1v5 librest-0.7-0 libsoup-gnome2.4-1
#   libsoup2.4-1 libu2f-udev libvulkan1 libxtst6
# Suggested packages:
#   indicator-application colord gvfs
# The following NEW packages will be installed:
#   at-spi2-core dconf-gsettings-backend dconf-service glib-networking
#   glib-networking-common glib-networking-services google-chrome-stable
#   gsettings-desktop-schemas libappindicator3-1 libatk-bridge2.0-0
#   libatspi2.0-0 libcairo-gobject2 libcolord2 libdbusmenu-glib4
#   libdbusmenu-gtk3-4 libdconf1 libepoxy0 libgtk-3-0 libgtk-3-bin
#   libgtk-3-common libindicator3-7 libjson-glib-1.0-0 libjson-glib-1.0-common
#   libproxy1v5 librest-0.7-0 libsoup-gnome2.4-1 libsoup2.4-1 libu2f-udev
#   libvulkan1 libxtst6
# 0 upgraded, 30 newly installed, 0 to remove and 8 not upgraded.
# Need to get 4,101 kB/72.8 MB of archives.
# After this operation, 251 MB of additional disk space will be used.
# Get:1 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libdbusmenu-glib4 amd64 16.04.1+18.04.20171206-0ubuntu2 [41.0 kB]
# Get:2 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libdbusmenu-gtk3-4 amd64 16.04.1+18.04.20171206-0ubuntu2 [26.8 kB]
# Get:3 http://mirror.kakao.com/ubuntu bionic/main amd64 libdconf1 amd64 0.26.0-2ubuntu3 [33.1 kB]
# Get:4 http://mirror.kakao.com/ubuntu bionic/main amd64 dconf-service amd64 0.26.0-2ubuntu3 [28.4 kB]
# Get:5 http://mirror.kakao.com/ubuntu bionic/main amd64 dconf-gsettings-backend amd64 0.26.0-2ubuntu3 [20.0 kB]
# Get:6 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libgtk-3-common all 3.22.30-1ubuntu4 [229 kB]
# Get:7 http://mirror.kakao.com/ubuntu bionic/main amd64 libatspi2.0-0 amd64 2.28.0-1 [59.6 kB]
# Get:8 http://mirror.kakao.com/ubuntu bionic/main amd64 libatk-bridge2.0-0 amd64 2.26.2-1 [57.3 kB]
# Get:9 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libcairo-gobject2 amd64 1.15.10-2ubuntu0.1 [17.1 kB]
# Get:10 http://mirror.kakao.com/ubuntu bionic/main amd64 libcolord2 amd64 1.3.3-2build1 [107 kB]
# Get:11 http://mirror.kakao.com/ubuntu bionic/main amd64 libepoxy0 amd64 1.4.3-1 [181 kB]
# Get:12 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libjson-glib-1.0-common all 1.4.2-3ubuntu0.18.04.1 [3,480 B]
# Get:13 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libjson-glib-1.0-0 amd64 1.4.2-3ubuntu0.18.04.1 [58.4 kB]
# Get:14 http://mirror.kakao.com/ubuntu bionic/main amd64 libproxy1v5 amd64 0.4.15-1 [49.5 kB]
# Get:15 http://mirror.kakao.com/ubuntu bionic/main amd64 glib-networking-common all 2.56.0-1 [3,324 B]
# Get:16 http://mirror.kakao.com/ubuntu bionic/main amd64 glib-networking-services amd64 2.56.0-1 [8,488 B]
# Get:17 http://mirror.kakao.com/ubuntu bionic/main amd64 gsettings-desktop-schemas all 3.28.0-1ubuntu1 [27.8 kB]
# Get:18 http://mirror.kakao.com/ubuntu bionic/main amd64 glib-networking amd64 2.56.0-1 [56.7 kB]
# Get:19 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libsoup2.4-1 amd64 2.62.1-1ubuntu0.4 [292 kB]
# Get:20 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libsoup-gnome2.4-1 amd64 2.62.1-1ubuntu0.4 [5,088 B]
# Get:21 http://mirror.kakao.com/ubuntu bionic/main amd64 librest-0.7-0 amd64 0.8.0-2 [31.8 kB]
# Get:22 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libgtk-3-0 amd64 3.22.30-1ubuntu4 [2,503 kB]
# Get:23 http://mirror.kakao.com/ubuntu bionic/main amd64 libindicator3-7 amd64 16.10.0+18.04.20180321.1-0ubuntu1 [26.1 kB]
# Get:24 http://mirror.kakao.com/ubuntu bionic/main amd64 libappindicator3-1 amd64 12.10.1+18.04.20180322.1-0ubuntu1 [19.4 kB]
# Get:25 http://mirror.kakao.com/ubuntu bionic/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:26 http://mirror.kakao.com/ubuntu bionic/main amd64 at-spi2-core amd64 2.28.0-1 [47.9 kB]
# Get:27 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libgtk-3-bin amd64 3.22.30-1ubuntu4 [57.4 kB]
# Get:28 http://mirror.kakao.com/ubuntu bionic-updates/main amd64 libu2f-udev all 1.1.4-1ubuntu0.1 [3,884 B]
# Get:29 http://mirror.kakao.com/ubuntu bionic-updates/universe amd64 libvulkan1 amd64 1.1.70+dfsg1-1ubuntu0.18.04.1 [93.4 kB]
# Get:30 /home/jovyan/anari-github/test-selenium-1/download/google-chrome-stable_current_amd64.deb google-chrome-stable amd64 83.0.4103.97-1 [68.7 MB]
# Fetched 4,101 kB in 3s (1,537 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package libdbusmenu-glib4:amd64.
# (Reading database ... 118533 files and directories currently installed.)
# Preparing to unpack .../00-libdbusmenu-glib4_16.04.1+18.04.20171206-0ubuntu2_amd64.deb ...
# Unpacking libdbusmenu-glib4:amd64 (16.04.1+18.04.20171206-0ubuntu2) ...
# Selecting previously unselected package libdbusmenu-gtk3-4:amd64.
# Preparing to unpack .../01-libdbusmenu-gtk3-4_16.04.1+18.04.20171206-0ubuntu2_amd64.deb ...
# Unpacking libdbusmenu-gtk3-4:amd64 (16.04.1+18.04.20171206-0ubuntu2) ...
# Selecting previously unselected package libdconf1:amd64.
# Preparing to unpack .../02-libdconf1_0.26.0-2ubuntu3_amd64.deb ...
# Unpacking libdconf1:amd64 (0.26.0-2ubuntu3) ...
# Selecting previously unselected package dconf-service.
# Preparing to unpack .../03-dconf-service_0.26.0-2ubuntu3_amd64.deb ...
# Unpacking dconf-service (0.26.0-2ubuntu3) ...
# Selecting previously unselected package dconf-gsettings-backend:amd64.
# Preparing to unpack .../04-dconf-gsettings-backend_0.26.0-2ubuntu3_amd64.deb ...
# Unpacking dconf-gsettings-backend:amd64 (0.26.0-2ubuntu3) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../05-libgtk-3-common_3.22.30-1ubuntu4_all.deb ...
# Unpacking libgtk-3-common (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../06-libatspi2.0-0_2.28.0-1_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.28.0-1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../07-libatk-bridge2.0-0_2.26.2-1_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.26.2-1) ...
# Selecting previously unselected package libcairo-gobject2:amd64.
# Preparing to unpack .../08-libcairo-gobject2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-gobject2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libcolord2:amd64.
# Preparing to unpack .../09-libcolord2_1.3.3-2build1_amd64.deb ...
# Unpacking libcolord2:amd64 (1.3.3-2build1) ...
# Selecting previously unselected package libepoxy0:amd64.
# Preparing to unpack .../10-libepoxy0_1.4.3-1_amd64.deb ...
# Unpacking libepoxy0:amd64 (1.4.3-1) ...
# Selecting previously unselected package libjson-glib-1.0-common.
# Preparing to unpack .../11-libjson-glib-1.0-common_1.4.2-3ubuntu0.18.04.1_all.deb ...
# Unpacking libjson-glib-1.0-common (1.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libjson-glib-1.0-0:amd64.
# Preparing to unpack .../12-libjson-glib-1.0-0_1.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libjson-glib-1.0-0:amd64 (1.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../13-libproxy1v5_0.4.15-1_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.15-1) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../14-glib-networking-common_2.56.0-1_all.deb ...
# Unpacking glib-networking-common (2.56.0-1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../15-glib-networking-services_2.56.0-1_amd64.deb ...
# Unpacking glib-networking-services (2.56.0-1) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../16-gsettings-desktop-schemas_3.28.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (3.28.0-1ubuntu1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../17-glib-networking_2.56.0-1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.56.0-1) ...
# Selecting previously unselected package libsoup2.4-1:amd64.
# Preparing to unpack .../18-libsoup2.4-1_2.62.1-1ubuntu0.4_amd64.deb ...
# Unpacking libsoup2.4-1:amd64 (2.62.1-1ubuntu0.4) ...
# Selecting previously unselected package libsoup-gnome2.4-1:amd64.
# Preparing to unpack .../19-libsoup-gnome2.4-1_2.62.1-1ubuntu0.4_amd64.deb ...
# Unpacking libsoup-gnome2.4-1:amd64 (2.62.1-1ubuntu0.4) ...
# Selecting previously unselected package librest-0.7-0:amd64.
# Preparing to unpack .../20-librest-0.7-0_0.8.0-2_amd64.deb ...
# Unpacking librest-0.7-0:amd64 (0.8.0-2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../21-libgtk-3-0_3.22.30-1ubuntu4_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libindicator3-7.
# Preparing to unpack .../22-libindicator3-7_16.10.0+18.04.20180321.1-0ubuntu1_amd64.deb ...
# Unpacking libindicator3-7 (16.10.0+18.04.20180321.1-0ubuntu1) ...
# Selecting previously unselected package libappindicator3-1.
# Preparing to unpack .../23-libappindicator3-1_12.10.1+18.04.20180322.1-0ubuntu1_amd64.deb ...
# Unpacking libappindicator3-1 (12.10.1+18.04.20180322.1-0ubuntu1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../24-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package google-chrome-stable.
# Preparing to unpack .../25-google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (83.0.4103.97-1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../26-at-spi2-core_2.28.0-1_amd64.deb ...
# Unpacking at-spi2-core (2.28.0-1) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../27-libgtk-3-bin_3.22.30-1ubuntu4_amd64.deb ...
# Unpacking libgtk-3-bin (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libu2f-udev.
# Preparing to unpack .../28-libu2f-udev_1.1.4-1ubuntu0.1_all.deb ...
# Unpacking libu2f-udev (1.1.4-1ubuntu0.1) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../29-libvulkan1_1.1.70+dfsg1-1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.1.70+dfsg1-1ubuntu0.18.04.1) ...
# Setting up libvulkan1:amd64 (1.1.70+dfsg1-1ubuntu0.18.04.1) ...
# Setting up libjson-glib-1.0-common (1.4.2-3ubuntu0.18.04.1) ...
# Setting up glib-networking-common (2.56.0-1) ...
# Setting up libatspi2.0-0:amd64 (2.28.0-1) ...
# Setting up libcairo-gobject2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libproxy1v5:amd64 (0.4.15-1) ...
# Setting up glib-networking-services (2.56.0-1) ...
# Setting up libu2f-udev (1.1.4-1ubuntu0.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up libjson-glib-1.0-0:amd64 (1.4.2-3ubuntu0.18.04.1) ...
# Setting up libdbusmenu-glib4:amd64 (16.04.1+18.04.20171206-0ubuntu2) ...
# Setting up libepoxy0:amd64 (1.4.3-1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.26.2-1) ...
# Setting up libdconf1:amd64 (0.26.0-2ubuntu3) ...
# Setting up libcolord2:amd64 (1.3.3-2build1) ...
# Setting up dconf-service (0.26.0-2ubuntu3) ...
# Setting up libdbusmenu-gtk3-4:amd64 (16.04.1+18.04.20171206-0ubuntu2) ...
# Setting up at-spi2-core (2.28.0-1) ...
# Setting up dconf-gsettings-backend:amd64 (0.26.0-2ubuntu3) ...
# Setting up gsettings-desktop-schemas (3.28.0-1ubuntu1) ...
# Setting up libgtk-3-common (3.22.30-1ubuntu4) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.6) ...
# Setting up glib-networking:amd64 (2.56.0-1) ...
# Setting up libsoup2.4-1:amd64 (2.62.1-1ubuntu0.4) ...
# Setting up libsoup-gnome2.4-1:amd64 (2.62.1-1ubuntu0.4) ...
# Setting up librest-0.7-0:amd64 (0.8.0-2) ...
# Setting up libgtk-3-0:amd64 (3.22.30-1ubuntu4) ...
# Setting up libgtk-3-bin (3.22.30-1ubuntu4) ...
# Setting up libindicator3-7 (16.10.0+18.04.20180321.1-0ubuntu1) ...
# Setting up libappindicator3-1 (12.10.1+18.04.20180322.1-0ubuntu1) ...
# Setting up google-chrome-stable (83.0.4103.97-1) ...
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/google-chrome (google-chrome) in auto mode
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# --2020-06-05 01:11:41--  https://chromedriver.storage.googleapis.com/83.0.4103.39/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 34.64.4.16, 2404:f340:10:1800::2010
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|34.64.4.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5222065 (5.0M) [application/zip]
# Saving to: ‘chromedriver_linux64.zip’
#
# chromedriver_linux6 100%[===================>]   4.98M  1.12MB/s    in 4.4s
#
# 2020-06-05 01:11:46 (1.13 MB/s) - ‘chromedriver_linux64.zip’ saved [5222065/5222065]
#
# Archive:  chromedriver_linux64.zip
#   inflating: chromedriver
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 47 kB/s eta 0:00:016
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.7/site-packages (from selenium) (1.25.9)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from time import sleep
from selenium.webdriver import Chrome

# %%
# create a new chrome session
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
driver = webdriver.Chrome(options=options)
# !mkdir -p result
# !mkdir -p 'result/1'

import time

from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.chrome.options import Options

if __name__ == '__main__':
    # 1. Optional Options (Useful for development testing)
    options = Options()
    options.add_argument("--disable-web-security")
    options.add_argument("--disable-application-cache")

    # 2. Create the Chrome Driver
    #driver = webdriver.Chrome(options=options)

    # 3. Head to the JsonPlaceholder landing page
    driver.get("https://jsonplaceholder.typicode.com/")
    driver.save_screenshot('result/1/2.png')

    # 4. Scroll to the run-message element to bring it into view (Optional)
    actions = ActionChains(driver)
    actions.move_to_element(driver.find_element_by_css_selector("#run-message"))
    actions.perform()
    driver.save_screenshot('result/1/4.png')

    # 5. Interact with the site
    driver.find_element_by_css_selector("#run-button").click() # Get the Run Button Element and Click it
    time.sleep(1) # Small Sleep for Async request to go out and DOM be updated
    driver.save_screenshot('result/1/5.png')

    # 6. Confirm the success message was present on the site
    print("Congrats you've made your first call to JSONPlaceholder! 😃 🎉" == driver.find_element_by_css_selector("#run-message").text)
    driver.save_screenshot('result/1/6.png')

    # 7. Close the driver to kill the chrome instance
    driver.close()

    # 2. Create the Chrome Driver
    #driver = webdriver.Chrome(options=options)
# Out:
# True

# %%
# create a new chrome session
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
driver = webdriver.Chrome(options=options)
import pandas as pd 
# !mkdir -p 'result/2'

pages = 10

for page in range(1,pages):

    url = "http://quotes.toscrape.com/js/page/" + str(page) + "/"

    driver.get(url)

    items = len(driver.find_elements_by_class_name("quote"))

    total = []
    for item in range(items):
        quotes = driver.find_elements_by_class_name("quote")
        for quote in quotes:
            quote_text = quote.find_element_by_class_name('text').text
            author = quote.find_element_by_class_name('author').text
            new = ((quote_text,author))
            total.append(new)
    df = pd.DataFrame(total,columns=['quote','author'])
    df.to_csv('result/2/quoted.csv')
driver.close()
